# %% [markdown]
# The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/docs You’ll need to start by signing up for an API key. Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %% [markdown]
# I will begin by importing the modules neccessary to complate the tasks in the assignment.

# %%
import pandas as pd
import json
import urllib.request
from pandas.io.json import json_normalize

# %% [markdown]
# Now I can begin to use the API key I requested. I will read the JSON data in the Most Popular Articles in the business section that were viewed the most.

# %%
api_key = 'a84d0eec3bae444db86213db7159856c'
url = 'http://api.nytimes.com/svc/mostpopular/v2/mostviewed/business/30.json?'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

# %% [markdown]
# This information is ready to be put into a dataframe.

# %%
mostviewed_bus = pd.read_json(response)
mostviewed_bus
# Out:
#                                             copyright  num_results  \
# 0   Copyright (c) 2018 The New York Times Company....          163
# 1   Copyright (c) 2018 The New York Times Company....          163
# 2   Copyright (c) 2018 The New York Times Company....          163
# 3   Copyright (c) 2018 The New York Times Company....          163
# 4   Copyright (c) 2018 The New York Times Company....          163
# 5   Copyright (c) 2018 The New York Times Company....          163
# 6   Copyright (c) 2018 The New York Times Company....          163
# 7   Copyright (c) 2018 The New York Times Company....          163
# 8   Copyright (c) 2018 The New York Times Company....          163
# 9   Copyright (c) 2018 The New York Times Company....          163
# 10  Copyright (c) 2018 The New York Times Company....          163
# 11  Copyright (c) 2018 The New York Times Company....          163
# 12  Copyright (c) 2018 The New York Times Company....          163
# ...

# %% [markdown]
# The data as presented is not very useful or readable. I will now use JSON to tidy up the data to make it more presentable.

# %%
data = json.loads(response)
most_shared = json_normalize(data['results'])
most_shared.sort_values(by=["views"], ascending=False)
# Out:
#                                              abstract  \
# 19  President Trump said he would consider tariffs...
# 18  In Mr. Abloh, Louis Vuitton has hired its firs...
# 17  An alliance of law firms, marketers, finance c...
# 16  The prizes encompassed, among other topics, st...
# 15  The major credit card networks are ending a re...
# 14  Production delays, a recall and other problems...
# 13  Settlement agreements — now made public after ...
# 12  Older Americans without children to lean on ha...
# 11  A top Morgan Stanley broker was repeatedly acc...
# 10  At least five agency officials were reassigned...
# 9   The May 29 date was announced after days of ou...
# 8   Mr. Jones and his conspiracy theory website In...
# 7   The company outlined the inventory buildup in ...
# 6   An egg farm in Hyde County, N.C., is the likel...
# 5   Last month, anchors at local news stations acr...
# 4   The pornographic film actress, whose real name...
# ...

# %% [markdown]
# Now the data is presentable and easy to read.
